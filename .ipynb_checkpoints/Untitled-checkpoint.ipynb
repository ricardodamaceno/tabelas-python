# %%
import pandas as pd

tabelas = pd.read_excel("fechamento-crediario-fake.xls")
display(tabelas)
# Out:
# _locate_stream(Workbook): seen
#     0  5 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
#    20  4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
#   140= 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4
#   160  4 4 4 4 3 2 2
# CompDocErrorTraceback (most recent call last)
# <ipython-input-1-2715e7870069> in <module>()
#       1 import pandas as pd
#       2
# ----> 3 tabelas = pd.read_excel("fechamento-crediario-fake.xls")
#       4
#       5 view = tabelas.loc(1, "Nome do Cliente")
#
# /usr/local/lib/python2.7/dist-packages/pandas/util/_decorators.pyc in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
#     190     return _deprecate_kwarg
#
# /usr/local/lib/python2.7/dist-packages/pandas/util/_decorators.pyc in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# ...
